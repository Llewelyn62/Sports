# %% [markdown]
# # Netball sport analytics

# %% [markdown]
# This is a prototype for importing and using sportdata to predict future outcomes.

# %%
from bs4 import BeautifulSoup
import urllib

# %%
url = 'https://anzpremiership.co.nz/fixtures-and-results/seasons'
page = urllib.request.urlopen(url).read()
soup = BeautifulSoup(page,"lxml")

# %%
#Print out the page tags
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>
#         <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>
#         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>
#         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Schedules and results, news and comprehensive stats for New Zealand's premier netball tournament" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="http://anzpremiership.co.nz/Images/Assets/4002/1/" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="
# 	Schedules and results, news and comprehensive stats for New Zealand's premier netball tournament
# " property="og:description"/>
# ...

# %% [markdown]
# This is rather a difficult process... best option is to try an html table and read that using pandas.

# %%
results_2017_table = pd.read_html("http://www.mynetball.co.nz/magic/draws-and-results.html", header=0)
df1 = results_2017_table[0]
df1
# Out:
# [Empty DataFrame
#  Columns: [Show more matches]
#  Index: []]

# %%
#Also, read in the season results and overall stats.
season_stats_2017 = pd.read_html("https://anzpremiership.co.nz/fixtures-and-results/ladder")
type(season_stats_2017[0])
# Out:
# pandas.core.frame.DataFrame

# %%
res = """ROUND - 1
SUN
26
MAR
 
Southern Steel
75
 VS 
Northern Stars
57
 
Claudelands Arena, Hamilton
#STEvSTA #ANZP
 Sky Sport 
Match Centre
SUN
26
MAR
 
WBOP Magic
71
 VS 
Mainland Tactix
48
 
Claudelands Arena, Hamilton
#MAGvTAC #ANZP
 Sky Sport 
Match Centre
SUN
26
MAR
 
Northern Mystics
55
 VS 
Central Pulse
56
 
Claudelands Arena, Hamilton
#MYSvPUL #ANZP
 Sky Sport 
Match Centre
MON
27
MAR
 
WBOP Magic
67
 VS 
Northern Stars
47
 
Claudelands Arena, Hamilton
#MAGvSTA #ANZP
 Sky Sport 
Match Centre
ROUND - 2
SUN
02
APR
 
Mainland Tactix
37
 VS 
Northern Stars
48
 
Horncastle Arena
#TACvSTA #ANZP
 Sky Sport 
Match Centre
MON
03
APR
 
Northern Mystics
67
 VS 
Southern Steel
74
 
The Trusts Arena, Auckland
#MYSvSTE #ANZP
 Sky Sport 
Match Centre
WED
05
APR
 
WBOP Magic
52
 VS 
Central Pulse
50
 
Energy Events Centre, Rotorua
#MAGvPUL #ANZP
 Sky Sport 
Match Centre
ROUND - 3
SUN
09
APR
 
Central Pulse
48
 VS 
Mainland Tactix
37
 
TSB Bank Arena, Wellington
#PULvTAC #ANZP
 Sky Sport 
Match Centre
MON
10
APR
 
Southern Steel
72
 VS 
WBOP Magic
59
 
ILT Stadium Southland, Invercargill
#STEvMAG #ANZP
 Sky Sport 
Match Centre
WED
12
APR
 
Northern Stars
44
 VS 
Northern Mystics
58
 
Vodafone Events Centre, Manukau
#STAvMYS #ANZP
 Sky Sport 
Match Centre
ROUND - 4
SUN
16
APR
 
Northern Mystics
67
 VS 
WBOP Magic
62
 
The Trusts Arena, Auckland
#MYSvMAG #ANZP
 Sky Sport 
Match Centre
MON
17
APR
 
Northern Stars
44
 VS 
Central Pulse
53
 
Vodafone Events Centre, Manukau
#STAvPUL #ANZP
 Sky Sport 
Match Centre
WED
19
APR
 
Mainland Tactix
41
 VS 
Southern Steel
90
 
Horncastle Arena
#TACvSTE #ANZP
 Sky Sport 
Match Centre
ROUND - 5
SUN
23
APR
 
Mainland Tactix
46
 VS 
WBOP Magic
61
 
Horncastle Arena
#TACvMYS #ANZP
 Sky Sport 
Match Centre
MON
24
APR
 
Central Pulse
47
 VS 
Northern Mystics
43
 
TSB Bank Arena, Wellington
 Sky Sport 
Match Centre
ROUND - 12
SUN
11
JUN
 
WBOP Magic
59
 VS 
Southern Steel
78
 
The Trusts Arena, Auckland
#MAGvSTE #ANZP
 Sky Sport 
Match Centre
SUN
11
JUN
 
Northern Mystics
60
 VS 
Northern Stars
54
 
The Trusts Arena, Auckland
#MYSvSTA #ANZP
 Sky Sport 
Match Centre
SUN
11
JUN
 
Central Pulse
56
 VS 
Mainland Tactix
37
 
The Trusts Arena, Auckland
#PULvTAC #ANZP
 Sky Sport 
Match Centre
MON
12
JUN
 
Northern Mystics
59
 VS 
WBOP Magic
58
 
The Trusts Arena, Auckland
#MYSvMAG #ANZP
 Sky Sport 
Match Centre
WED
14
JUN
 
Mainland Tactix
46
 VS 
Southern Steel
51
 
Horncastle Arena
#TACvSTE #ANZP
 Sky Sport 
Match Centre
WED
14
JUN
 
Central Pulse
57
 VS 
Northern Stars
47
 
Te Rauparaha Arena, Porirua
#PULvSTA #ANZP
 Sky Sport 
Match Centre
ROUND - 13
SUN
18
JUN
 
Northern Mystics
46
 VS 
Mainland Tactix
57
 
The Trusts Arena, Auckland
#MYSvTAC #ANZP
 Sky Sport 
Match Centre
MON
19
JUN
 
Southern Steel
64
 VS 
Central Pulse
51
 
ILT Stadium Southland, Invercargill
#STEvPUL #ANZP
 Sky Sport 
Match Centre
WED
21
JUN
 
WBOP Magic
58
 VS 
Northern Stars
45
 
ASB BayPark Arena
#MAGvSTA #ANZP
 Sky Sport 
Match Centre
ROUND - FINAL
SUN
25
JUN
 
Central Pulse
59
 VS 
Northern Mystics
52
 
TSB Bank Arena, Wellington
#ANZPFinals
 Sky Sport 
Match Centre
WED
28
JUN
 
Southern Steel
69
 VS 
Central Pulse
53
 
ILT Stadium Southland, Invercargill
#ANZPGF #ANZPFinals
 Sky Sport 
Match Centre"""

res = res.strip().split('Centre')
df4 = pd.DataFrame(res)
df4
# Out:
#                                                     0
# 0   ROUND - 1\nSUN\n26\nMAR\n \nSouthern Steel\n75...
# 1   \nSUN\n26\nMAR\n \nWBOP Magic\n71\n VS \nMainl...
# 2   \nSUN\n26\nMAR\n \nNorthern Mystics\n55\n VS \...
# 3   \nMON\n27\nMAR\n \nWBOP Magic\n67\n VS \nNorth...
# 4   \nROUND - 2\nSUN\n02\nAPR\n \nMainland Tactix\...
# 5   \nMON\n03\nAPR\n \nNorthern Mystics\n67\n VS \...
# 6   \nWED\n05\nAPR\n \nWBOP Magic\n52\n VS \nCentr...
# 7      , Rotorua\n#MAGvPUL #ANZP\n Sky Sport \nMatch
# 8   \nROUND - 3\nSUN\n09\nAPR\n \nCentral Pulse\n4...
# 9   \nMON\n10\nAPR\n \nSouthern Steel\n72\n VS \nW...
# 10  \nWED\n12\nAPR\n \nNorthern Stars\n44\n VS \nN...
# 11     , Manukau\n#STAvMYS #ANZP\n Sky Sport \nMatch
# 12  \nROUND - 4\nSUN\n16\nAPR\n \nNorthern Mystics...
# 13  \nMON\n17\nAPR\n \nNorthern Stars\n44\n VS \nC...
# 14     , Manukau\n#STAvPUL #ANZP\n Sky Sport \nMatch
# 15  \nWED\n19\nAPR\n \nMainland Tactix\n41\n VS \n...
# ...

# %%
from io import StringIO
data = StringIO(res)
df4 = pd.read_csv(data)
df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-fac03c9301f9> in <module>()
#       1 res = res.strip().split('Centre')
#       2 from io import StringIO
# ----> 3 data = StringIO(res)
#       4 df4 = pd.read_csv(data)
#       5 df4
#
# TypeError: initial_value must be str or None, not list
